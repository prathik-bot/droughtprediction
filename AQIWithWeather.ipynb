# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Flatten
# from keras import optimizers
from tensorflow.keras import optimizers 

from sklearn.model_selection import train_test_split

# %%
cols_to_drop = ['latitude', 'longitude', 'city']
cols = ['aqi', 'temperature_2m', 'relative_humidity_2m', 
       'wind_speed_10m', 'pressure_msl', 'precipitation', 'cloud_cover']

# %%
df = pd.read_csv('Data/Final/San_Jose___Jackson.csv')
df.drop(cols_to_drop, axis=1, inplace=True)
df.set_index(['date'], inplace=True)
df = df[cols]
df.head()
# Out:
#               aqi  temperature_2m  relative_humidity_2m  wind_speed_10m  \
# date
# 2014-01-01  154.0       10.993118             42.393568        8.427079
# 2014-01-02   96.0       12.511500             41.723330        8.878908
# 2014-01-03   95.0       14.938583             37.342059        7.806972
# 2014-01-04   83.0       14.390667             40.825293        6.490594
# 2014-01-05   70.0       11.257333             47.339449        7.805876
#
#             pressure_msl  precipitation  cloud_cover
# date
# 2014-01-01   1021.341176            0.0    31.823529
# 2014-01-02   1019.933333            0.0    44.041667
# 2014-01-03   1017.075000            0.0    92.541667
# 2014-01-04   1015.345833            0.0    55.375000
# 2014-01-05   1018.612500            0.0     0.000000

# %%
minimum = []
maximum = []
minimum.append(df['aqi'].min())
maximum.append(df['aqi'].max())

cols = df.columns.values.tolist()

scaler = MinMaxScaler(feature_range=(0, 1))
df[cols] = scaler.fit_transform(df[cols])

df.head()
# Out:
#                  aqi  temperature_2m  relative_humidity_2m  wind_speed_10m  \
# date
# 2014-01-01  0.736842        0.223888              0.299862        0.226908
# 2014-01-02  0.459330        0.277988              0.291430        0.242174
# 2014-01-03  0.454545        0.364465              0.236308        0.205957
# 2014-01-04  0.397129        0.344943              0.280131        0.161481
# 2014-01-05  0.334928        0.233302              0.362088        0.205920
#
#             pressure_msl  precipitation  cloud_cover
# date
# 2014-01-01      0.658160            0.0     0.318235
# 2014-01-02      0.622135            0.0     0.440417
# 2014-01-03      0.548992            0.0     0.925417
# 2014-01-04      0.504745            0.0     0.553750
# 2014-01-05      0.588336            0.0     0.000000

# %%
def create_lagged_features(df, lag_steps, target_col='temperature_2m'):
    for lag in range(1, lag_steps + 1):
        df[f'{target_col}_(t-{lag})'] = df[target_col].shift(lag)
    return df


lag_steps = 2

df = create_lagged_features(df, lag_steps, target_col='aqi')

df = df.dropna()
df.head()
# Out:
#                  aqi  temperature_2m  relative_humidity_2m  wind_speed_10m  \
# date
# 2014-01-03  0.454545        0.364465              0.236308        0.205957
# 2014-01-04  0.397129        0.344943              0.280131        0.161481
# 2014-01-05  0.334928        0.233302              0.362088        0.205920
# 2014-01-06  0.416268        0.276355              0.388041        0.146433
# 2014-01-07  0.416268        0.332027              0.384985        0.142131
#
#             pressure_msl  precipitation  cloud_cover  aqi_(t-1)  aqi_(t-2)
# date
# 2014-01-03      0.548992            0.0     0.925417   0.459330   0.736842
# 2014-01-04      0.504745            0.0     0.553750   0.454545   0.459330
# 2014-01-05      0.588336            0.0     0.000000   0.397129   0.454545
# 2014-01-06      0.684721            0.0     0.484167   0.334928   0.397129
# 2014-01-07      0.666276            0.0     0.914167   0.416268   0.334928

# %%
correlation_matrix = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
X = df.drop(columns=['aqi']).values
y = df['aqi'].values

temp1 = int(0.8*len(X))
temp2 = int(0.1*len(X))
X_train = X[:temp1]
X_val = X[temp1:temp1+temp2]
X_test = X[temp1+temp2:]

y_train = y[:temp1]
y_val = y[temp1:temp1+temp2]
y_test = y[temp1+temp2:]

print(X_train.shape, X_val.shape, X_test.shape)
print(y_train.shape, y_val.shape, y_test.shape)
# Out:
# (3287, 8) (410, 8) (412, 8)
# (3287,) (410,) (412,)

# %%
look_back = 1
length_of_col = X_train.shape[1]

X_train = X_train.reshape((X_train.shape[0], look_back, length_of_col))
X_test = X_test.reshape((X_test.shape[0], look_back, length_of_col))
X_val = X_val.reshape((X_val.shape[0], look_back, length_of_col))

print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# (3287, 1, 8) (410, 1, 8) (412, 1, 8)

# %%
epoch = 100
model = Sequential()


model.add((LSTM(units=64, return_sequences=True, input_shape=(look_back, X_train.shape[2]), activation='relu')))
model.add(Dropout(0.2))
model.add((LSTM(units=32, return_sequences=True, activation='relu')))
model.add(Dropout(0.2))

model.add(Flatten())

model.add(Dense(units = 1, activation='sigmoid'))

# learning rate with decay
adam = optimizers.Adam(learning_rate=0.001)

model.compile(loss = 'mean_squared_error', optimizer = adam)

history = model.fit(X_train[:-1], y_train[1:], validation_data=(X_val[:-1], y_val[1:]), epochs=epoch, batch_size=50,verbose=1, shuffle = False)
model.summary()
# Out:
# Epoch 1/100
# /Users/vgurumurthy/Downloads/aqiprediction-main/aqipred/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0854 - val_loss: 0.0428
# Epoch 2/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0202 - val_loss: 0.0077
# Epoch 3/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0097 - val_loss: 0.0072
# Epoch 4/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0093 - val_loss: 0.0068
# Epoch 5/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0088 - val_loss: 0.0066
# Epoch 6/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0084 - val_loss: 0.0063
# Epoch 7/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0081 - val_loss: 0.0061
# Epoch 8/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0079 - val_loss: 0.0059
# Epoch 9/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0076 - val_loss: 0.0058
# Epoch 10/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0074 - val_loss: 0.0056
# Epoch 11/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0070 - val_loss: 0.0056
# Epoch 12/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0072 - val_loss: 0.0057
# Epoch 13/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0070 - val_loss: 0.0056
# Epoch 14/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0069 - val_loss: 0.0056
# Epoch 15/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0066 - val_loss: 0.0056
# Epoch 16/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0067 - val_loss: 0.0055
# Epoch 17/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0069 - val_loss: 0.0055
# Epoch 18/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0067 - val_loss: 0.0056
# Epoch 19/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0063 - val_loss: 0.0056
# Epoch 20/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0066 - val_loss: 0.0055
# Epoch 21/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0065 - val_loss: 0.0055
# Epoch 22/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0066 - val_loss: 0.0055
# Epoch 23/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0066 - val_loss: 0.0055
# Epoch 24/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0065 - val_loss: 0.0054
# Epoch 25/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0065 - val_loss: 0.0055
# Epoch 26/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0065 - val_loss: 0.0054
# Epoch 27/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0064 - val_loss: 0.0054
# Epoch 28/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0064 - val_loss: 0.0054
# Epoch 29/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0066 - val_loss: 0.0054
# Epoch 30/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0063 - val_loss: 0.0054
# Epoch 31/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0062 - val_loss: 0.0054
# Epoch 32/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0063 - val_loss: 0.0054
# Epoch 33/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0062 - val_loss: 0.0054
# Epoch 34/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0062 - val_loss: 0.0054
# Epoch 35/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 36/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0064 - val_loss: 0.0054
# Epoch 37/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0062 - val_loss: 0.0054
# Epoch 38/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 39/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0060 - val_loss: 0.0054
# Epoch 40/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0062 - val_loss: 0.0054
# Epoch 41/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0062 - val_loss: 0.0054
# Epoch 42/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 43/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 44/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0060 - val_loss: 0.0054
# Epoch 45/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0060 - val_loss: 0.0054
# Epoch 46/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0060 - val_loss: 0.0054
# Epoch 47/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0062 - val_loss: 0.0053
# Epoch 48/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 49/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0062 - val_loss: 0.0054
# Epoch 50/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 51/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0060 - val_loss: 0.0053
# Epoch 52/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0060 - val_loss: 0.0054
# Epoch 53/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 54/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0060 - val_loss: 0.0054
# Epoch 55/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 56/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0060 - val_loss: 0.0053
# Epoch 57/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0059 - val_loss: 0.0054
# Epoch 58/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0060 - val_loss: 0.0053
# Epoch 59/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0058 - val_loss: 0.0054
# Epoch 60/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0060 - val_loss: 0.0053
# Epoch 61/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0059 - val_loss: 0.0053
# Epoch 62/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 63/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 64/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0059 - val_loss: 0.0053
# Epoch 65/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 66/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0061 - val_loss: 0.0053
# Epoch 67/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 68/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 69/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0059 - val_loss: 0.0053
# Epoch 70/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 71/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 72/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 73/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 74/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 75/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 76/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 77/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 78/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 79/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 80/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 81/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 82/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 83/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 84/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 85/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 86/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 87/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 88/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 89/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 90/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 91/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 92/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 93/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 94/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 95/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 96/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 97/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 98/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 99/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0055 - val_loss: 0.0053
# Epoch 100/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0056 - val_loss: 0.0053
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 1, 64)          │        18,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 1, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 1, 32)          │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 1, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 93,413 (364.90 KB)
#  Trainable params: 31,137 (121.63 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 62,276 (243.27 KB)

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(8, 5))  # Set figure size for better readability

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss', color='blue', linestyle='solid')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red', linestyle='dashed')

# Titles and labels
plt.title('Model Loss Over Epochs - One Day', fontsize=14)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss', fontsize=12)

# Add a legend and grid for clarity
plt.legend(loc='upper right', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)

# Show the plot
plt.show()

# %%
look_back = 1
length_of_col = X_train.shape[1]  # This should be 8, the number of features

# Check if the reshaping is feasible
total_elements = X_train.shape[0] * X_train.shape[1]  # Total elements before reshape
expected_elements_after_reshape = X_train.shape[0] * look_back * length_of_col  # Total elements after reshape

print(f"Total elements in X_train before reshape: {total_elements}")
print(f"Expected total elements after reshape: {expected_elements_after_reshape}")
# Out:
# Total elements in X_train before reshape: 3287
# Expected total elements after reshape: 3287

# %%
# Get the final loss values from history
final_train_loss_1day = history.history['loss'][-1]
final_val_loss_1day = history.history['val_loss'][-1]

print("1-Day Prediction Model:")
print(f"Final Training Loss: {final_train_loss_1day:.4f}")
print(f"Final Validation Loss: {final_val_loss_1day:.4f}")
# Out:
# 1-Day Prediction Model:
# Final Training Loss: 0.0062
# Final Validation Loss: 0.0053

# %%
def recursive_forecast_for_all(model, X_data, steps=2):
    all_predictions = []  # Store predictions for all rows

    for row in range(len(X_data)):
        predictions = [np.nan] * steps
        X_data_copy = X_data.copy()  

        for i in range(steps):
            if row + i >= len(X_data):
                break

            temp_input = X_data_copy[row + i].copy()
            temp_input_reshaped = temp_input.reshape(1, 1, -1)
            pred = model.predict(temp_input_reshaped, verbose=0)
            predictions[i] = pred[0][0] 
            if row + i + 1 < len(X_data_copy):
                X_data_copy[row + i + 1][0][-2:] = [pred[0][0], temp_input[0][-2]]  

        all_predictions.append(predictions)

    return all_predictions

one_day_forecast = recursive_forecast_for_all(model, X_test, steps=7)

# %%
forecast_length = len(one_day_forecast)
test_df = df[-forecast_length:].copy()

columns = [f"pred_aqi_(t+{i})" if i > 0 else "pred_aqi" for i in range(1,len(one_day_forecast[0])+1)]


forecast_df = pd.DataFrame(one_day_forecast, columns=columns)
forecast_df.index = test_df.index
forecast_df['aqi_(t+1)'] = test_df['aqi'].shift(-1)

forecast_df = forecast_df * (maximum[0] - minimum[0]) + minimum[0]
forecast_df.tail(10)
# Out:
#             pred_aqi_(t+1)  pred_aqi_(t+2)  pred_aqi_(t+3)  pred_aqi_(t+4)  \
# date
# 2025-03-25       53.417473       43.177515       34.211590       35.314830
# 2025-03-26       43.682232       34.383645       35.405576       40.129723
# 2025-03-27       34.275734       35.313971       40.090304       28.042915
# 2025-03-28       38.918781       43.156397       28.682875       32.377731
# 2025-03-29       41.864067       28.284261       32.241728       34.216716
# 2025-03-30       27.002529       31.537120       34.034583       29.956158
# 2025-03-31       30.002655       33.232179       29.823945       29.486762
# 2025-04-01       33.077202       29.782257       29.478194             NaN
# 2025-04-02       28.811245       29.177028             NaN             NaN
# 2025-04-03       30.895597             NaN             NaN             NaN
#
#             pred_aqi_(t+5)  pred_aqi_(t+6)  pred_aqi_(t+7)  aqi_(t+1)
# date
# 2025-03-25       40.083082       28.041909       32.102168       43.0
# 2025-03-26       28.053526       32.106631       34.182636       48.0
# 2025-03-27       32.102729       34.181428       29.986906       35.0
# 2025-03-28       34.260463       30.002783       29.531851       33.0
# 2025-03-29       29.994365       29.529830             NaN       17.0
# 2025-03-30       29.521057             NaN             NaN       29.0
# 2025-03-31             NaN             NaN             NaN       25.0
# 2025-04-01             NaN             NaN             NaN       43.0
# 2025-04-02             NaN             NaN             NaN       43.0
# 2025-04-03             NaN             NaN             NaN        NaN

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=16, 
                    validation_data=(X_test, y_test), verbose=1)

# Predict
y_pred = model.predict(X_test)
# Out:
# Epoch 1/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.0044 - val_loss: 0.0023
# Epoch 2/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 3/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 4/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - loss: 0.0037 - val_loss: 0.0021
# Epoch 5/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - loss: 0.0037 - val_loss: 0.0022
# Epoch 6/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 0.0038 - val_loss: 0.0021
# Epoch 7/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - loss: 0.0040 - val_loss: 0.0022
# Epoch 8/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - loss: 0.0038 - val_loss: 0.0021
# Epoch 9/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 10/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - loss: 0.0042 - val_loss: 0.0026
# Epoch 11/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 12/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - loss: 0.0041 - val_loss: 0.0023
# Epoch 13/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - loss: 0.0037 - val_loss: 0.0022
# Epoch 14/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 0.0040 - val_loss: 0.0022
# Epoch 15/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 0.0036 - val_loss: 0.0022
# Epoch 16/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0036 - val_loss: 0.0024
# Epoch 17/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - loss: 0.0039 - val_loss: 0.0022
# Epoch 18/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 19/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 20/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - loss: 0.0039 - val_loss: 0.0022
# Epoch 21/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 0.0036 - val_loss: 0.0024
# Epoch 22/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - loss: 0.0038 - val_loss: 0.0023
# Epoch 23/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 24/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 0.0037 - val_loss: 0.0021
# Epoch 25/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 0.0036 - val_loss: 0.0022
# Epoch 26/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - loss: 0.0034 - val_loss: 0.0023
# Epoch 27/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - loss: 0.0036 - val_loss: 0.0024
# Epoch 28/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 29/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 30/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 31/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 32/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 33/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 34/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 35/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - loss: 0.0036 - val_loss: 0.0022
# Epoch 36/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 37/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 38/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 39/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - loss: 0.0036 - val_loss: 0.0023
# Epoch 40/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 41/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 42/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - loss: 0.0038 - val_loss: 0.0022
# Epoch 43/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - loss: 0.0038 - val_loss: 0.0022
# Epoch 44/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 45/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 46/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - loss: 0.0036 - val_loss: 0.0022
# Epoch 47/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 48/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 49/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - loss: 0.0038 - val_loss: 0.0024
# Epoch 50/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - loss: 0.0034 - val_loss: 0.0023
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import pandas as pd

results = []

# Assuming 'aqi_(t+1)' is the observed AQI column
for col in forecast_df.columns:
    if col.startswith("pred_aqi_"):
        # Extract lag from the column name, for example 'pred_aqi_(t+1)', 'pred_aqi_(t+2)'
        lag = int(col.split("_(t+")[1].strip(")")) if "(t+" in col else 0

        # Adjust 'aqi_(t+1)' based on its lag relationship with predictions
        actual_column = 'aqi_(t+1)'  # Adjust this if the observed AQI column has a different name
        actual = forecast_df[actual_column][lag:].reset_index(drop=True)
        predicted = forecast_df[col][:-lag].reset_index(drop=True)

        # Ensure lengths match
        min_len = min(len(actual), len(predicted))
        actual = actual[:min_len]
        predicted = predicted[:min_len]

        # Drop NaN values
        mask = ~np.isnan(actual) & ~np.isnan(predicted)
        actual = actual[mask]
        predicted = predicted[mask]

        # Check if non-empty after removing NaNs
        if len(actual) == 0 or len(predicted) == 0:
            print(f"Skipping column {col} due to insufficient data.")
            continue

        # Calculate metrics
        rmse = np.sqrt(mean_squared_error(actual, predicted))
        mape = np.mean(np.abs((actual - predicted) / actual)) * 100
        r2 = r2_score(actual, predicted)

        results.append({
            "Prediction Horizon": col,
            "RMSE": rmse,
            "R²": r2
        })

# Convert results to DataFrame
metrics_df = pd.DataFrame(results)
print(metrics_df)
# Out:
#   Prediction Horizon       RMSE        R²
# 0     pred_aqi_(t+1)  13.964464  0.210960
# 1     pred_aqi_(t+2)  14.564593  0.139324
# 2     pred_aqi_(t+3)  15.387171  0.035753
# 3     pred_aqi_(t+4)  15.779269 -0.014815
# 4     pred_aqi_(t+5)  15.965423 -0.036512
# 5     pred_aqi_(t+6)  16.186000 -0.063108
# 6     pred_aqi_(t+7)  16.367487 -0.085280

# %%
plt.figure(figsize=(15, 8))
ax = plt.gca()

if "aqi_(t+1)" in forecast_df and "pred_aqi_(t+1)" in forecast_df:
    forecast_df["aqi_(t+1)"].plot(ax=ax, label="Actual AQI", linestyle='-', linewidth=2, color='blue')
    forecast_df["pred_aqi_(t+1)"].plot(ax=ax, label="Predicted AQI", linestyle='-', linewidth=2, color='orange')

    ax.set_title("Actual AQI vs Predicted AQI", fontsize=16)
    ax.set_xlabel("Date", fontsize=14)
    ax.set_ylabel("AQI", fontsize=14)
    ax.legend(loc="upper left", fontsize=12)

    plt.xticks(rotation=45)
    ax.grid(True, linestyle='--', alpha=0.6)

    plt.tight_layout()
    plt.show()
else:
    print("Column names do not match! Check `forecast_df.columns` output.")

# %%
# Ensure the index is a DatetimeIndex
forecast_df.index = pd.to_datetime(forecast_df.index)

# Filter the data from 2024 onwards
forecast_df_2025 = forecast_df[forecast_df.index.year >= 2025]

# Plot the data
plt.figure(figsize=(15, 8))  # Set figure size
ax = plt.gca()  # Get the current axis

# Plot Actual AQI and Predicted AQI from 2024 onward
forecast_df_2025['aqi_(t+1)'].plot(ax=ax, label="Actual AQI", linestyle='-', linewidth=2, color='blue')
forecast_df_2025['pred_aqi_(t+1)'].plot(ax=ax, label="Predicted AQI", linestyle='-', linewidth=2, color='orange')

# Titles and labels
ax.set_title("Actual AQI vs Predicted AQI (2025 For One Day)", fontsize=16)
ax.set_xlabel("Date", fontsize=14)
ax.set_ylabel("AQI", fontsize=14)

ax.legend(loc="upper left", fontsize=12)

# Rotate x-axis ticks for better visibility
plt.xticks(rotation=45)

# Add grid
ax.grid(True, linestyle='--', alpha=0.6)

# Show the plot
plt.tight_layout()
plt.show()
